# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import numpy as np

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
new_columns = ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS', 'ASK_AMT', 'IS_SUCCESSFUL']
clean_df = application_df[new_columns].copy()
clean_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
app_counts = clean_df.value_counts('APPLICATION_TYPE')
application_types_to_replace =  app_counts[app_counts <500].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
class_counts = clean_df.value_counts('CLASSIFICATION')
classifications_to_replace = class_counts[class_counts <1000].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
cols_to_convert = ['USE_CASE', 'INCOME_AMT']
dummy_df = pd.get_dummies(clean_df,columns = cols_to_convert,  prefix=cols_to_convert)
dummy_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION  ORGANIZATION  STATUS  \
# 0              T10       Independent          C1000   Association       1
# 1               T3       Independent          C2000  Co-operative       1
# 2               T5  CompanySponsored          C3000   Association       1
# 3               T3  CompanySponsored          C2000         Trust       1
# 4               T3       Independent          C1000         Trust       1
#
#   SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL  USE_CASE_CommunityServ  \
# 0                      N     5000              1                   False
# 1                      N   108590              1                   False
# 2                      N     5000              0                   False
# 3                      N     6692              1                   False
# 4                      N   142590              1                   False
#
#    USE_CASE_Heathcare  ...  USE_CASE_ProductDev  INCOME_AMT_0  \
# 0               False  ...                 True          True
# 1               False  ...                False         False
# 2               False  ...                 True          True
# 3               False  ...                False         False
# 4                True  ...                False         False
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M
# 0            False              False
# 1            False              False
# 2            False              False
# 3            False              False
# 4            False              False
#
# [5 rows x 22 columns]

# %%
#Look at Ask Amt value counts
ask_counts = clean_df.value_counts('ASK_AMT')
filt_ask_counts = ask_counts.loc[ask_counts >1]
print(filt_ask_counts)
# Out:
# ASK_AMT
# 5000     25398
# 63981        3
# 10478        3
# 15583        3
# 6725         3
#          ...
# 5255         2
# 5731         2
# 5175         2
# 5470         2
# 5179         2
# Name: count, Length: 152, dtype: int64

# %%
#Create bins of Ask Amt
# Define the bin edges
bin_edges = [0, 5000, 10000, 50000, 100000, 500000, 1000000, float('inf')]

# Define the bin labels
bin_labels = ['0-5000','5001-10000', '10001-50000', '50001-100000', '100001-500000', '500001-1000000', '1000000+']

# Create bins using pd.cut()
clean_df['ASK_AMT_bins'] = pd.cut(clean_df['ASK_AMT'], bins=bin_edges, labels=bin_labels)

# Display the counts of values in each bin
bin_counts = clean_df['ASK_AMT_bins'].value_counts().sort_index()
print(bin_counts)
# Out:
# ASK_AMT_bins
# 0-5000            25398
# 5001-10000          549
# 10001-50000        2398
# 50001-100000       1423
# 100001-500000      2304
# 500001-1000000      650
# 1000000+           1577
# Name: count, dtype: int64

# %%
#Create new DF for PCA
pca_df = dummy_df[['USE_CASE_CommunityServ', 'USE_CASE_Heathcare', 'USE_CASE_Other', 'USE_CASE_Preservation', 'USE_CASE_ProductDev', 'IS_SUCCESSFUL', 'INCOME_AMT_0', 'INCOME_AMT_1-9999', 'INCOME_AMT_10000-24999', 'INCOME_AMT_100000-499999', 'INCOME_AMT_10M-50M', 'INCOME_AMT_1M-5M',
            'INCOME_AMT_25000-99999', 'INCOME_AMT_50M+', 'INCOME_AMT_5M-10M']]
merged_df = pd.merge(pca_df, clean_df[['ASK_AMT_bins']], left_index=True, right_index=True)
merged_df = pd.get_dummies(merged_df, columns=['ASK_AMT_bins'])
pca_df_numeric = merged_df.select_dtypes(include=[np.number])
# Create a PCA model instance
pca = PCA(n_components=21)

# Use the PCA model with `fit_transform`
pca_result = pca.fit_transform(merged_df)
scaled_pca = pd.DataFrame(data=pca_result)
# Get the PCA components
pca_components = pd.DataFrame(pca.components_, columns=merged_df.columns)

# Print the PCA components
print("PCA Components:")
print(pca_components)
# Out:
# PCA Components:
#     USE_CASE_CommunityServ  USE_CASE_Heathcare  USE_CASE_Other  \
# 0                -0.006163            0.007144        0.000098
# 1                 0.019880            0.008874        0.000147
# 2                 0.005370            0.001999       -0.000172
# 3                 0.000821            0.002083       -0.000148
# 4                -0.000966            0.048785        0.000306
# 5                -0.000476           -0.012104        0.000067
# 6                 0.002952           -0.009097        0.000506
# 7                -0.009726           -0.021172        0.000179
# 8                -0.034302           -0.062247        0.000717
# 9                -0.013750           -0.014841       -0.000127
# 10                0.073969            0.033646        0.000815
# 11                0.747812            0.129551        0.001964
# 12               -0.033109            0.015479       -0.001340
# 13               -0.132510            0.081510       -0.001608
# 14               -0.149399            0.277448        0.001638
# 15               -0.310780            0.612636        0.002576
# 16               -0.096983            0.211228        0.002507
# 17                0.190981           -0.467857       -0.003207
# 18               -0.223459           -0.228260        0.894407
# 19                0.039035            0.039035        0.039035
# 20               -0.175661           -0.175661       -0.175661
#
#     USE_CASE_Preservation  USE_CASE_ProductDev  IS_SUCCESSFUL  INCOME_AMT_0  \
# 0                0.059518            -0.060598   6.453200e-02     -0.634850
# 1               -0.712556             0.683655  -1.235993e-01     -0.055281
# 2                0.087902            -0.095099  -9.891817e-01     -0.023670
# 3               -0.014610             0.011853  -9.058400e-04     -0.000091
# 4               -0.020945            -0.027181   3.013506e-02     -0.120553
# 5                0.006332             0.006180  -4.420334e-03      0.026394
# 6               -0.001867             0.007506  -3.890797e-03     -0.038552
# 7                0.014763             0.015956  -3.164615e-02     -0.410467
# 8                0.044620             0.051212   3.661084e-03      0.175786
# 9                0.009733             0.018985  -7.708195e-04     -0.108639
# 10              -0.050311            -0.058120   1.039680e-03      0.129847
# 11              -0.419926            -0.459401   1.022719e-02     -0.000909
# 12               0.006873             0.012097  -2.427855e-03     -0.301752
# 13               0.029516             0.023091   1.283845e-03      0.238768
# 14              -0.063275            -0.066411   9.162239e-04     -0.098256
# 15              -0.150425            -0.154007  -2.444420e-04     -0.027856
# 16              -0.057096            -0.059656   3.630781e-04     -0.218061
# 17               0.139115             0.140967   2.246563e-03     -0.177284
# 18              -0.221277            -0.221411  -1.999632e-04      0.000158
# 19               0.039035             0.039035   6.591949e-17     -0.263318
# 20              -0.175661            -0.175661  -1.110223e-16      0.177533
#
#     INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  ...  \
# 0            0.024951                0.025525                  0.237225  ...
# 1            0.002312                0.000755                  0.003817  ...
# 2           -0.019100               -0.007054                  0.008579  ...
# 3           -0.003970               -0.005393                  0.647123  ...
# 4            0.039142                0.012963                 -0.355011  ...
# 5           -0.056289               -0.058371                 -0.139741  ...
# 6           -0.010740               -0.041401                  0.129316  ...
# 7            0.684652                0.252492                 -0.216869  ...
# 8           -0.199830                0.148331                 -0.218128  ...
# 9           -0.092957               -0.197233                  0.265657  ...
# 10          -0.299608                0.536291                 -0.095891  ...
# 11           0.041148               -0.045345                 -0.026398  ...
# 12          -0.323314                0.606132                  0.015531  ...
# 13           0.259614               -0.070686                 -0.211027  ...
# 14          -0.108235               -0.098589                 -0.027278  ...
# 15          -0.033533               -0.028904                 -0.011625  ...
# 16          -0.234864               -0.226065                 -0.114717  ...
# 17          -0.185346               -0.185732                 -0.132601  ...
# 18           0.000453                0.000444                  0.000115  ...
# 19          -0.263318               -0.263318                 -0.263318  ...
# 20           0.177533                0.177533                  0.177533  ...
#
#     INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M  \
# 0                 0.260578         0.007463           0.010167
# 1                 0.032516         0.003915           0.002661
# 2                 0.010729         0.004204           0.002957
# 3                -0.677153         0.002226           0.003145
# 4                -0.198053         0.054928           0.069638
# 5                 0.322392        -0.015602          -0.018177
# 6                 0.132290        -0.007279          -0.009685
# 7                -0.217777        -0.021141          -0.023992
# 8                -0.187023        -0.074150          -0.082953
# 9                 0.213834        -0.019689          -0.020116
# 10               -0.102506         0.036424           0.040881
# 11               -0.017235         0.041512          -0.012550
# 12                0.026396         0.018277           0.028787
# 13               -0.159715         0.088833           0.139194
# 14               -0.034735         0.010147          -0.487857
# 15               -0.013710         0.562614          -0.071276
# 16               -0.124886        -0.131756           0.781186
# 17               -0.135964         0.730667           0.015971
# 18               -0.000102         0.001460          -0.000699
# 19               -0.263318        -0.263318          -0.263318
# 20                0.177533         0.177533           0.177533
#
#     ASK_AMT_bins_0-5000  ASK_AMT_bins_5001-10000  ASK_AMT_bins_10001-50000  \
# 0             -0.613025                 0.033682                  0.175257
# 1             -0.062614                 0.002544                  0.022244
# 2             -0.044995                -0.003678                  0.003835
# 3             -0.032830                -0.023753                 -0.242008
# 4             -0.111183                 0.021119                 -0.420324
# 5              0.044484                 0.009965                 -0.593526
# 6              0.022649                 0.043769                 -0.389352
# 7              0.209738                 0.191127                 -0.086004
# 8             -0.266405                -0.065757                  0.103083
# 9              0.127204                 0.189295                 -0.230785
# 10            -0.268340                 0.607832                 -0.108825
# 11            -0.007216                -0.115044                  0.021541
# 12             0.320115                -0.533294                 -0.025321
# 13            -0.362037                -0.313151                  0.018028
# 14             0.076937                 0.057470                  0.021372
# 15             0.022274                 0.017951                  0.007792
# 16             0.116814                 0.081015                  0.037235
# 17             0.051590                 0.030394                  0.018665
# 18             0.000017                -0.001938                  0.000195
# 19            -0.229395                -0.229395                 -0.229395
# 20            -0.283361                -0.283361                 -0.283361
#
#     ASK_AMT_bins_50001-100000  ASK_AMT_bins_100001-500000  \
# 0                    0.098841                    0.168330
# 1                    0.005469                    0.014860
# 2                    0.003871                    0.004249
# 3                    0.024508                    0.244979
# 4                   -0.045025                   -0.144931
# 5                    0.007134                    0.697859
# 6                    0.781759                   -0.408232
# 7                   -0.038887                   -0.016753
# 8                    0.201962                    0.062158
# 9                   -0.418779                   -0.278850
# 10                  -0.102597                   -0.057867
# 11                   0.025704                    0.023011
# 12                  -0.001457                    0.007593
# 13                   0.057944                    0.088986
# 14                   0.015951                    0.001877
# 15                   0.008544                    0.003252
# 16                   0.027904                    0.008346
# 17                   0.013153                    0.007012
# 18                  -0.000594                    0.000324
# 19                  -0.229395                   -0.229395
# 20                  -0.283361                   -0.283361
#
#     ASK_AMT_bins_500001-1000000  ASK_AMT_bins_1000000+
# 0                      0.041317               0.095597
# 1                      0.001628               0.015869
# 2                      0.003917               0.032800
# 3                      0.006856               0.022249
# 4                      0.051878               0.648468
# 5                     -0.007517              -0.158399
# 6                      0.042507              -0.093099
# 7                      0.066285              -0.325505
# 8                      0.389443              -0.424483
# 9                      0.677249              -0.065332
# 10                    -0.033117              -0.037086
# 11                     0.107603              -0.055599
# 12                     0.160976               0.071388
# 13                     0.440956               0.069273
# 14                    -0.030659              -0.142949
# 15                    -0.006832              -0.052981
# 16                    -0.044657              -0.226657
# 17                    -0.008889              -0.111926
# 18                     0.000724               0.001272
# 19                    -0.229395              -0.229395
# 20                    -0.283361              -0.283361
#
# [21 rows x 22 columns]

# %%
# Split our preprocessed data into our features and target arrays, with fewer inputs than in original model, using only use case
X = dummy_df[['USE_CASE_CommunityServ', 'USE_CASE_Heathcare', 'USE_CASE_Other', 'USE_CASE_Preservation', 'USE_CASE_ProductDev']]
y = dummy_df["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train2)

# Scale the data
X_train_scaled2 = X_scaler.transform(X_train2)
X_test_scaled2 = X_scaler.transform(X_test2)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn2 = tf.keras.models.Sequential()

# Add the input layer
nn2.add(tf.keras.layers.Input(shape=(X_train_scaled2.shape[1],)))

# First hidden layer
nn2.add(tf.keras.layers.Dense(units=5, activation='relu', input_dim=5))

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=5, activation='relu'))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66 (264.00 Byte)
# Trainable params: 66 (264.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_nn2 = nn2.fit(X_train2, y_train2, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 6s 5ms/step - loss: 0.6916 - accuracy: 0.5318
# Epoch 2/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.6912 - accuracy: 0.5318
# Epoch 3/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6910 - accuracy: 0.5318
# Epoch 4/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6909 - accuracy: 0.5318
# Epoch 5/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6908 - accuracy: 0.5318
# Epoch 6/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6908 - accuracy: 0.5332
# Epoch 7/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6908 - accuracy: 0.5351
# Epoch 8/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6907 - accuracy: 0.5355
# Epoch 9/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6907 - accuracy: 0.5358
# Epoch 10/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6907 - accuracy: 0.5360
# Epoch 11/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6906 - accuracy: 0.5362
# Epoch 12/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6907 - accuracy: 0.5362
# Epoch 13/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6907 - accuracy: 0.5362
# Epoch 14/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6906 - accuracy: 0.5362
# Epoch 15/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6906 - accuracy: 0.5362
# Epoch 16/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6906 - accuracy: 0.5362
# Epoch 17/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6906 - accuracy: 0.5362
# Epoch 18/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6906 - accuracy: 0.5362
# Epoch 19/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6905 - accuracy: 0.5362
# Epoch 20/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6906 - accuracy: 0.5362
# Epoch 21/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6905 - accuracy: 0.5362
# Epoch 22/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6905 - accuracy: 0.5362
# Epoch 23/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6905 - accuracy: 0.5362
# Epoch 24/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6905 - accuracy: 0.5362
# Epoch 25/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6904 - accuracy: 0.5362
# Epoch 26/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6904 - accuracy: 0.5362
# Epoch 27/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6904 - accuracy: 0.5362
# Epoch 28/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6904 - accuracy: 0.5362
# Epoch 29/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6904 - accuracy: 0.5362
# Epoch 30/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6904 - accuracy: 0.5362
# Epoch 31/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6904 - accuracy: 0.5362
# Epoch 32/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6903 - accuracy: 0.5362
# Epoch 33/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6903 - accuracy: 0.5362
# Epoch 34/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6904 - accuracy: 0.5362
# Epoch 35/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6904 - accuracy: 0.5362
# Epoch 36/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6903 - accuracy: 0.5362
# Epoch 37/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6904 - accuracy: 0.5362
# Epoch 38/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6903 - accuracy: 0.5362
# Epoch 39/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 40/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6903 - accuracy: 0.5362
# Epoch 41/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6903 - accuracy: 0.5362
# Epoch 42/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6902 - accuracy: 0.5356
# Epoch 43/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6904 - accuracy: 0.5362
# Epoch 44/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 45/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6903 - accuracy: 0.5356
# Epoch 46/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6903 - accuracy: 0.5362
# Epoch 47/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6903 - accuracy: 0.5362
# Epoch 48/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6903 - accuracy: 0.5362
# Epoch 49/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6903 - accuracy: 0.5360
# Epoch 50/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6903 - accuracy: 0.5362

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled2, y_test2,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.9057 - accuracy: 0.4718 - 492ms/epoch - 2ms/step
# Loss: 0.9056698679924011, Accuracy: 0.47183674573898315

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn3 = tf.keras.models.Sequential()

# Add the input layer
nn3.add(tf.keras.layers.Input(shape=(X_train_scaled2.shape[1],)))

# First hidden layer
nn3.add(tf.keras.layers.Dense(units=5, activation='relu', input_dim=5))

# Second hidden layer and adjust units
nn3.add(tf.keras.layers.Dense(units=3, activation='relu'))

#Third hidden layer with increased neurons
nn3.add(tf.keras.layers.Dense(units=25, activation='relu'))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 5)                 30
#
#  dense_4 (Dense)             (None, 3)                 18
#
#  dense_5 (Dense)             (None, 25)                100
#
#  dense_6 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 174 (696.00 Byte)
# Trainable params: 174 (696.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_nn3 = nn3.fit(X_train_scaled2, y_train2, epochs=75)
# Out:
# Epoch 1/75
# 804/804 [==============================] - 3s 2ms/step - loss: 0.6907 - accuracy: 0.5336
# Epoch 2/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6905 - accuracy: 0.5334
# Epoch 3/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6904 - accuracy: 0.5353
# Epoch 4/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6904 - accuracy: 0.5351
# Epoch 5/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6902 - accuracy: 0.5348
# Epoch 6/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6903 - accuracy: 0.5341
# Epoch 7/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6903 - accuracy: 0.5353
# Epoch 8/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6903 - accuracy: 0.5360
# Epoch 9/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6903 - accuracy: 0.5348
# Epoch 10/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 11/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.6903 - accuracy: 0.5362
# Epoch 12/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 13/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 14/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 15/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 16/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 17/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6900 - accuracy: 0.5362
# Epoch 18/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 19/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 20/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 21/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 22/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 23/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 24/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 25/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 26/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 27/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 28/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 29/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 30/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 31/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 32/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 33/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 34/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 35/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 36/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 37/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 38/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 39/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 40/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 41/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 42/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 43/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 44/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 45/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 46/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 47/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 48/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 49/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 50/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 51/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 52/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 53/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 54/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 55/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 56/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 57/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6900 - accuracy: 0.5362
# Epoch 58/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6900 - accuracy: 0.5362
# Epoch 59/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 60/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6900 - accuracy: 0.5362
# Epoch 61/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 62/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 63/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 64/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 65/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6900 - accuracy: 0.5362
# Epoch 66/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 67/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6902 - accuracy: 0.5362
# Epoch 68/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 69/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 70/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 71/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 72/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 73/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 74/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362
# Epoch 75/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.5362

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn3.evaluate(X_test_scaled2,y_test2,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6903 - accuracy: 0.5369 - 447ms/epoch - 2ms/step
# Loss: 0.6902990341186523, Accuracy: 0.5369096398353577

# %%
merged_df.head()
# Split our preprocessed data into our features and target arrays,  using only ask_amt
X3 = merged_df[['ASK_AMT_bins_0-5000', 'ASK_AMT_bins_5001-10000',  'ASK_AMT_bins_10001-50000', 'ASK_AMT_bins_50001-100000',  'ASK_AMT_bins_100001-500000', 'ASK_AMT_bins_500001-1000000',  'ASK_AMT_bins_1000000+']]
y3 = merged_df["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train3)

# Scale the data
X_train_scaled3 = X_scaler.transform(X_train3)
X_test_scaled3 = X_scaler.transform(X_test3)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn4 = tf.keras.models.Sequential()

# Add the input layer
nn4.add(tf.keras.layers.Input(shape=(X_train_scaled3.shape[1],)))

# First hidden layer
nn4.add(tf.keras.layers.Dense(units=7, activation='relu', input_dim=7))

# Second hidden layer
nn4.add(tf.keras.layers.Dense(units=7, activation='relu', input_dim=7))

# Third hidden layer, and increase number of neurons
nn4.add(tf.keras.layers.Dense(units=25, activation='relu', input_dim=7))

# Output layer
nn4.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn4.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 7)                 56
#
#  dense_8 (Dense)             (None, 7)                 56
#
#  dense_9 (Dense)             (None, 25)                200
#
#  dense_10 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 338 (1.32 KB)
# Trainable params: 338 (1.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn4.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
#Increase # of Epochs
fit_nn4 = nn4.fit(X_train3, y_train3, epochs=75)
# Out:
# Epoch 1/75
# 804/804 [==============================] - 3s 2ms/step - loss: 0.6906 - accuracy: 0.5347
# Epoch 2/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6896 - accuracy: 0.5379
# Epoch 3/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6894 - accuracy: 0.5379
# Epoch 4/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5365
# Epoch 5/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5379
# Epoch 6/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 7/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5379
# Epoch 8/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 9/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5379
# Epoch 10/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5379
# Epoch 11/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 12/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5379
# Epoch 13/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6893 - accuracy: 0.5379
# Epoch 14/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5379
# Epoch 15/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 16/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5379
# Epoch 17/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 18/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 19/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5379
# Epoch 20/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5379
# Epoch 21/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5379
# Epoch 22/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 23/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 24/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 25/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 26/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 27/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 28/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 29/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 30/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 31/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 32/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 33/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 34/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 35/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 36/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 37/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 38/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 39/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 40/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 41/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 42/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 43/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 44/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 45/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 46/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 47/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 48/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 49/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 50/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 51/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 52/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 53/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 54/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 55/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 56/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 57/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 58/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 59/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 60/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 61/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 62/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 63/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 64/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 65/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 66/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 67/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 68/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 69/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 70/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5379
# Epoch 71/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 72/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 73/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 74/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6890 - accuracy: 0.5379
# Epoch 75/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6890 - accuracy: 0.5379

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn4.evaluate(X_test_scaled3,y_test3,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.7143 - accuracy: 0.5355 - 456ms/epoch - 2ms/step
# Loss: 0.7142576575279236, Accuracy: 0.5355101823806763

# %%
#Rerun the model with Tanh & Softmax
#Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn5 = tf.keras.models.Sequential()

# Add the input layer
nn5.add(tf.keras.layers.Input(shape=(X_train_scaled3.shape[1],)))

# First hidden layer
nn5.add(tf.keras.layers.Dense(units=7, activation='tanh', input_dim=7))

# Second hidden layer
nn5.add(tf.keras.layers.Dense(units=7, activation='tanh', input_dim=7))

# Third hidden layer, and increase number of neurons
nn5.add(tf.keras.layers.Dense(units=17, activation='tanh', input_dim=7))

# Output layer
nn5.add(tf.keras.layers.Dense(units=1, activation='softmax'))

# Check the structure of the model
nn5.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 7)                 56
#
#  dense_12 (Dense)            (None, 7)                 56
#
#  dense_13 (Dense)            (None, 17)                136
#
#  dense_14 (Dense)            (None, 1)                 18
#
# =================================================================
# Total params: 266 (1.04 KB)
# Trainable params: 266 (1.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn5.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Run the model
fit_nn5 = nn5.fit(X_train3, y_train3, epochs=75)
# Out:
# Epoch 1/75
# 804/804 [==============================] - 3s 2ms/step - loss: 0.6924 - accuracy: 0.5318
# Epoch 2/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6897 - accuracy: 0.5318
# Epoch 3/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6894 - accuracy: 0.5318
# Epoch 4/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6893 - accuracy: 0.5318
# Epoch 5/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6894 - accuracy: 0.5318
# Epoch 6/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6895 - accuracy: 0.5318
# Epoch 7/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6894 - accuracy: 0.5318
# Epoch 8/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6893 - accuracy: 0.5318
# Epoch 9/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6893 - accuracy: 0.5318
# Epoch 10/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 11/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6893 - accuracy: 0.5318
# Epoch 12/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6893 - accuracy: 0.5318
# Epoch 13/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6893 - accuracy: 0.5318
# Epoch 14/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6893 - accuracy: 0.5318
# Epoch 15/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 16/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 17/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 18/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 19/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 20/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 21/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 22/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 23/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 24/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 25/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 26/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 27/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 28/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 29/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6889 - accuracy: 0.5318
# Epoch 30/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 31/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 32/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 33/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 34/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 35/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 36/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 37/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 38/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 39/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 40/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 41/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6892 - accuracy: 0.5318
# Epoch 42/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5318
# Epoch 43/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 44/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6890 - accuracy: 0.5318
# Epoch 45/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 46/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 47/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 48/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6890 - accuracy: 0.5318
# Epoch 49/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 50/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6889 - accuracy: 0.5318
# Epoch 51/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6890 - accuracy: 0.5318
# Epoch 52/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 53/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 54/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 55/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 56/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5318
# Epoch 57/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 58/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 59/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 60/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 61/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 62/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 63/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6890 - accuracy: 0.5318
# Epoch 64/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 65/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5318
# Epoch 66/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 67/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 68/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 69/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 70/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6890 - accuracy: 0.5318
# Epoch 71/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 72/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 73/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6891 - accuracy: 0.5318
# Epoch 74/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6890 - accuracy: 0.5318
# Epoch 75/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6891 - accuracy: 0.5318

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn5.evaluate(X_test_scaled3,y_test3,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6909 - accuracy: 0.5343 - 458ms/epoch - 2ms/step
# Loss: 0.6909289956092834, Accuracy: 0.5343440175056458

# %%
# Split our preprocessed data into our features and target arrays
X4 = dummy_df[['USE_CASE_CommunityServ', 'USE_CASE_Heathcare', 'USE_CASE_Other', 'USE_CASE_Preservation', 'USE_CASE_ProductDev', 'INCOME_AMT_0', 'INCOME_AMT_1-9999', 'INCOME_AMT_10000-24999', 'INCOME_AMT_100000-499999', 'INCOME_AMT_10M-50M', 'INCOME_AMT_1M-5M', 'INCOME_AMT_25000-99999', 'INCOME_AMT_50M+', 'INCOME_AMT_5M-10M']]
y4 = dummy_df["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train4, X_test4, y_train4, y_test4 = train_test_split(X4, y4, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler4 = scaler.fit(X_train4)

# Scale the data
X_train_scaled4 = X_scaler4.transform(X_train4)
X_test_scaled4 = X_scaler4.transform(X_test4)

# %%
#Rerun the model with Tanh & Softmax
#Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn6 = tf.keras.models.Sequential()

# Add the input layer
nn6.add(tf.keras.layers.Input(shape=(X_train_scaled4.shape[1],)))

# First hidden layer
nn6.add(tf.keras.layers.Dense(units=7, activation='relu', input_dim=7))

# Second hidden layer
nn6.add(tf.keras.layers.Dense(units=7, activation='relu', input_dim=7))

# Third hidden layer, and increase number of neurons
nn6.add(tf.keras.layers.Dense(units=25, activation='relu', input_dim=7))

# Output layer
nn6.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn6.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 7)                 105
#
#  dense_26 (Dense)            (None, 7)                 56
#
#  dense_27 (Dense)            (None, 25)                200
#
#  dense_28 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 387 (1.51 KB)
# Trainable params: 387 (1.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn6.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Run the model
fit_nn6 = nn6.fit(X_train_scaled4, y_train4, epochs=75)
# Out:
# Epoch 1/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6860 - accuracy: 0.5426
# Epoch 2/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6846 - accuracy: 0.5475
# Epoch 3/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6845 - accuracy: 0.5474
# Epoch 4/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6840 - accuracy: 0.5482
# Epoch 5/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6841 - accuracy: 0.5484
# Epoch 6/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6839 - accuracy: 0.5470
# Epoch 7/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6837 - accuracy: 0.5484
# Epoch 8/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6839 - accuracy: 0.5483
# Epoch 9/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6837 - accuracy: 0.5480
# Epoch 10/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6836 - accuracy: 0.5485
# Epoch 11/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6836 - accuracy: 0.5478
# Epoch 12/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6836 - accuracy: 0.5487
# Epoch 13/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6837 - accuracy: 0.5479
# Epoch 14/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6836 - accuracy: 0.5487
# Epoch 15/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6836 - accuracy: 0.5485
# Epoch 16/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6836 - accuracy: 0.5479
# Epoch 17/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6836 - accuracy: 0.5485
# Epoch 18/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6835 - accuracy: 0.5489
# Epoch 19/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6835 - accuracy: 0.5483
# Epoch 20/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6835 - accuracy: 0.5485
# Epoch 21/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6835 - accuracy: 0.5484
# Epoch 22/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6835 - accuracy: 0.5481
# Epoch 23/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6835 - accuracy: 0.5485
# Epoch 24/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6833 - accuracy: 0.5479
# Epoch 25/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6836 - accuracy: 0.5487
# Epoch 26/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6835 - accuracy: 0.5484
# Epoch 27/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6835 - accuracy: 0.5483
# Epoch 28/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6834 - accuracy: 0.5487
# Epoch 29/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6834 - accuracy: 0.5476
# Epoch 30/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6834 - accuracy: 0.5479
# Epoch 31/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6835 - accuracy: 0.5487
# Epoch 32/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6833 - accuracy: 0.5480
# Epoch 33/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6835 - accuracy: 0.5487
# Epoch 34/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6833 - accuracy: 0.5479
# Epoch 35/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6833 - accuracy: 0.5489
# Epoch 36/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5484
# Epoch 37/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6835 - accuracy: 0.5486
# Epoch 38/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.5488
# Epoch 39/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6834 - accuracy: 0.5487
# Epoch 40/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.5489
# Epoch 41/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6834 - accuracy: 0.5489
# Epoch 42/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6833 - accuracy: 0.5489
# Epoch 43/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6834 - accuracy: 0.5490
# Epoch 44/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6834 - accuracy: 0.5487
# Epoch 45/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.5487
# Epoch 46/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.5488
# Epoch 47/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5484
# Epoch 48/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.5487
# Epoch 49/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5480
# Epoch 50/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.5489
# Epoch 51/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6833 - accuracy: 0.5479
# Epoch 52/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6832 - accuracy: 0.5489
# Epoch 53/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.5483
# Epoch 54/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.5488
# Epoch 55/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5486
# Epoch 56/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5488
# Epoch 57/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.5488
# Epoch 58/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5479
# Epoch 59/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6832 - accuracy: 0.5487
# Epoch 60/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6832 - accuracy: 0.5484
# Epoch 61/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5489
# Epoch 62/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.5487
# Epoch 63/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6832 - accuracy: 0.5477
# Epoch 64/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5487
# Epoch 65/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5490
# Epoch 66/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6833 - accuracy: 0.5488
# Epoch 67/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6832 - accuracy: 0.5489
# Epoch 68/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6832 - accuracy: 0.5487
# Epoch 69/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5489
# Epoch 70/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5489
# Epoch 71/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5488
# Epoch 72/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5488
# Epoch 73/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6831 - accuracy: 0.5489
# Epoch 74/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6832 - accuracy: 0.5489
# Epoch 75/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6831 - accuracy: 0.5489

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn6.evaluate(X_test_scaled4,y_test4,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.6857 - accuracy: 0.5447 - 509ms/epoch - 2ms/step
# Loss: 0.6857037544250488, Accuracy: 0.5447230339050293
